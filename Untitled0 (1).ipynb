# %% [markdown]
# # Data structure Answers

# %% [markdown]
# 1.
#    -  Data structures are ways of organizing and storing data to perform
#       operations efficiently.
#       They're important because they help in solving complex problems & managing data effectively .
#
# 2.
#    -   Mutable data types Can be changed after creation.
#        Example - list, dict, set.
#
#        Immutable data types Cannot be changed after creation.
#        Example - strings, tuple.
# 3.
#    -   Lists are mutable. Tuples are immutable.
#        Lists use [] , tuple use () .
#
# 4.
#    -  Dictionaries store data in key-value pairs using a hash table.
#
# 5.
#    -  Sets automatically remove duplicates and provide unique elements.
#
# 6.
#    -  A string is a sequence of characters. whereas a list can contain multiple data types and is mutable.
#
# 7.
#    -  Being immutable, tuples prevent accidental modification.
#
# 8.
#    -  A hash table is a data structure that maps keys to values using a hash function.
#
# 9.
#    -  Yes, Python lists are heterogeneous.
#
# 10.
#    -  It ensuresmemory efficiency & security.
#
# 11.
#
#    -  Fast lookup using keys, insertion & deletion by key & Efficient data
#       organization.
#
# 12.
#    -  Such cases Where data should not change, like returning multiple values from a function. Here we can use tuples.
#
# 13.
#    -  Sets automatically eliminate duplicates when data is added.
#
# 14.
#    -  For Lists it Checks values presence & For Dictionary it Checks for keys.
#
# 15.
#    -  No, tuples are immutable, thats why their elements cannot be changed after creation.
#
# 16.
#    -  A dictionary inside another dictionary calls Nested Dictionary.
#       Such as,
#       students = {"John": {"age": 21, "grade": "A"}}
# 17.
#    -  Average case time complexity is O(1) due to hash-based lookups.
#
# 18.
#    -  When order matters or the data does not need to be accessed by key.
#
# 20.
#    -  Lists retrieve elements by index, while dictionaries retrieve values using keys.

# %% [markdown]
# # Coding

# %%
1.
    name = "kusal"
    print(name)

2.
   s = "Hello World"
   print(len(s))

3.
   s = "Python Programming"
   print(s[:3])

4.
   s = "hello"
   print(s.upper())

5.
   s = "I like apple"
   s.replace("apple", "orange")
   print(s)

6.
   num = [1, 2, 3, 4, 5]
   print(num)

7.
   list = [1, 2, 3, 4]
   list.append(10)
   print(list)

8.
   list = [1, 2, 3, 4, 5]
   list.remove(3)
   print(list)

9.
    c = ['a', 'b', 'c', 'd']
    print(c[1])

10.
    list = [10, 20, 30, 40, 50]
    print(list[::-1])

11.
    t = (100, 200, 300)
    print(t)

12.
    colors = ('red', 'green', 'blue', 'yellow')
    print(colors[-2])

13.
    num = (10, 20, 5, 15)
    print(min(num))

14.
    animals = ('dog', 'cat', 'rabbit')
    print(animals.index('cat'))

15.
    fruits = ("apple", "banana", "mango")
    print("kiwi" in fruits)

16.
    s = {'a', 'b', 'c'}
    print(s)

17.
    s = {1, 2, 3, 4, 5}
    s.clear()
    print(s)

18.
    s = {1, 2, 3, 4}
    s.remove(4)
    print(s)

19.
    a = {1, 2, 3}
    b = {3, 4, 5}
    print(a.union(b))

20.
    a = {1, 2, 3}
    b = {2, 3, 4}
    print(a.intersection(b))

21.
    p = {"name": "Alice", "age": 25, "city": "New York"}
    print(p)

22.
    p = {'name': 'John', 'age': 25}
    p["country"] = "USA"
    print(p)

23.
    p = {'name': 'Alice', 'age': 30}
    print(p["name"])

24.
    p = {'name': 'Bob', 'age': 22, 'city': 'New York'}
    del p['age']
    print(p)

25.
    person = {'name': 'Alice', 'city': 'Paris'}
    print("city" in person)

26.
    my_list = [1, 2, 3]
    my_tuple = (4, 5, 6)
    my_dict = {"a": 1, "b": 2}
    print(my_list, my_tuple, my_dict)

27.
    import random
    numbers = random.sample(range(1, 101), 5)
    numbers.sort()
    print(numbers)

28.
    s = ["apple", "banana", "cherry", "date", "fig"]
    print(s[3])

29.
    d1 = {"a": 1, "b": 2}
    d2 = {"c": 3, "d": 4}
    combined = {**d1, **d2}
    print(combined)
